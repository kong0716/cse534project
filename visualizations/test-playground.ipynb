# %% [markdown]
# # Progress Report Plots

# %% [markdown]
# ## Libraries

# %%
import os
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import folium
from folium import plugins
import branca
from pprint import pprint

# %matplotlib inline

# %% [markdown]
# ## Preprocessing

# %%
dataset_files = [os.path.join(dp, f) for dp, dn, filenames in os.walk("../results/") for f in filenames if os.path.splitext(f)[1] == '.csv']
website_files, network_files = [], []
for dataset_file in dataset_files:
    if "websites" in dataset_file:
        website_files.append(dataset_file)
    elif "network" in dataset_file:
        network_files.append(dataset_file)

website_df = pd.concat([pd.read_csv(f) for f in website_files], ignore_index=True)
network_df = pd.concat([pd.read_csv(f) for f in network_files], ignore_index=True)

# %%
website_df.head()
# Out:
#     destination  packet_transmit  packet_receive  packet_loss_count  \
# 0    google.com             40.0            40.0                0.0
# 1   youtube.com             40.0            39.0                1.0
# 2     tmall.com             40.0            40.0                0.0
# 3  facebook.com             40.0            39.0                1.0
# 4        qq.com             40.0            40.0                0.0
#
#    packet_loss_rate  rtt_min  rtt_avg  rtt_max  rtt_mdev  \
# 0               0.0    9.547   12.937   52.278     7.213
# 1               2.5   10.032   11.614   13.654     0.744
# 2               0.0  247.545  310.718  370.803    34.253
# 3               2.5   11.671   13.271   17.899     1.166
# 4               0.0  222.477  298.483  477.298    66.467
#
#    packet_duplicate_count  packet_duplicate_rate     jitter  loss_rate  \
# 0                     0.0                    0.0   3.751795        0.0
# 1                     0.0                    0.0   0.978947        2.5
# 2                     0.0                    0.0  38.846154        0.0
# 3                     0.0                    0.0   1.123684        2.5
# 4                     0.0                    0.0  66.641026        0.0
#
#    loss_count    location  latitude  longitude wifi_name
# 0         0.0  SchomburgA  40.91339  -73.13221   eduroam
# 1         1.0  SchomburgA  40.91339  -73.13221   eduroam
# 2         0.0  SchomburgA  40.91339  -73.13221   eduroam
# 3         1.0  SchomburgA  40.91339  -73.13221   eduroam
# 4         0.0  SchomburgA  40.91339  -73.13221   eduroam

# %%
website_df.isnull().sum()
# Out:
# destination               11
# packet_transmit           11
# packet_receive            11
# packet_loss_count         11
# packet_loss_rate          11
# rtt_min                   11
# rtt_avg                   11
# rtt_max                   11
# rtt_mdev                  11
# packet_duplicate_count    11
# packet_duplicate_rate     11
# jitter                     0
# loss_rate                 11
# loss_count                11
# location                   0
# latitude                   0
# longitude                  0
# wifi_name                  0
# dtype: int64

# %% [markdown]
# Some points from Roth Cafe and Frey Hall returned NaN values, so we will drop this from the dataset

# %%
website_df.dropna(axis=0, how="any", inplace=True)

# %%
website_df.isnull().sum()
# Out:
# destination               0
# packet_transmit           0
# packet_receive            0
# packet_loss_count         0
# packet_loss_rate          0
# rtt_min                   0
# rtt_avg                   0
# rtt_max                   0
# rtt_mdev                  0
# packet_duplicate_count    0
# packet_duplicate_rate     0
# jitter                    0
# loss_rate                 0
# loss_count                0
# location                  0
# latitude                  0
# longitude                 0
# wifi_name                 0
# dtype: int64

# %%
print(f"Length of website_df: {len(website_df)}")
# Out:
# Length of website_df: 1284

# %%
network_df.head()
# Out:
#                ssid  signal_strength      download        upload  \
# 0           eduroam              -44  2.225958e+08  2.192850e+08
# 1  WolfieNet-Secure              -43  1.902200e+08  1.206257e+08
# 2  WolfieNet-Secure              -48  2.544044e+08  1.418327e+08
# 3           eduroam              -50  2.135338e+08  1.309610e+08
# 4  WolfieNet-Secure              -49  1.974280e+08  1.745381e+08
#
#                    location   latitude  longitude         wifi_name
# 0                SchomburgA  40.913390 -73.132210           eduroam
# 1                SchomburgA  40.913390 -73.132210  WolfieNet-Secure
# 2                SchomburgA  40.913137 -73.132169  WolfieNet-Secure
# 3  Humanities2ndFloorLounge  40.914110 -73.121030           eduroam
# 4  Humanities2ndFloorLounge  40.914110 -73.121030  WolfieNet-Secure

# %%
network_df.isnull().sum()
# Out:
# ssid               0
# signal_strength    0
# download           0
# upload             0
# location           0
# latitude           0
# longitude          0
# wifi_name          0
# dtype: int64

# %%
print(f"Length of network_df: {len(network_df)}")
# Out:
# Length of network_df: 37

# %%
network_df
# Out:
#                 ssid  signal_strength      download        upload  \
# 0            eduroam              -44  2.225958e+08  2.192850e+08
# 1   WolfieNet-Secure              -43  1.902200e+08  1.206257e+08
# 2   WolfieNet-Secure              -48  2.544044e+08  1.418327e+08
# 3            eduroam              -50  2.135338e+08  1.309610e+08
# 4   WolfieNet-Secure              -49  1.974280e+08  1.745381e+08
# 5            eduroam              -62  9.956018e+07  1.357139e+08
# 6   WolfieNet-Secure              -60  1.137025e+08  1.365578e+08
# 7            eduroam              -48  2.483312e+08  1.734833e+08
# 8   WolfieNet-Secure              -42  2.034012e+08  1.686027e+08
# 9            eduroam              -53  2.144838e+08  2.208303e+08
# 10  WolfieNet-Secure              -50  1.806473e+08  2.038397e+08
# 11           eduroam              -45  1.989532e+08  2.023954e+08
# 12  WolfieNet-Secure              -45  1.917224e+08  2.172624e+08
# 13           eduroam              -64  7.940918e+07  8.281793e+07
# 14  WolfieNet-Secure              -64  8.345845e+06  2.898055e+06
# 15           eduroam              -60  4.156339e+07  8.475945e+07
# 16  WolfieNet-Secure              -52  4.725878e+07  6.163281e+07
# 17           eduroam              -55  6.705141e+07  1.021633e+08
# 18  WolfieNet-Secure              -56  1.064322e+07  9.290205e+06
# 19           eduroam              -49  2.103482e+08  2.029844e+08
# 20  WolfieNet-Secure              -48  2.465780e+08  2.353060e+08
# 21           eduroam              -60  3.647863e+07  6.754637e+07
# 22  WolfieNet-Secure              -80  6.079693e+07  2.260413e+07
# 23           eduroam              -49  2.085981e+08  2.164263e+08
# 24  WolfieNet-Secure              -46  2.027736e+08  1.698897e+08
# 25           eduroam              -60  7.387865e+07  7.990289e+07
# 26  WolfieNet-Secure              -59  5.100904e+07  6.128728e+07
# 27           eduroam              -58  7.690866e+06  2.655231e+07
# 28  WolfieNet-Secure              -49  1.003841e+08  1.240073e+08
# 29           eduroam              -52  6.339991e+07  8.781850e+07
# 30  WolfieNet-Secure              -51  5.519532e+07  7.161797e+07
# 31           eduroam              -63  1.557159e+08  1.799985e+07
# 32  WolfieNet-Secure              -59  1.810711e+08  7.005348e+07
# 33           eduroam              -67  7.346196e+07  1.485679e+08
# 34  WolfieNet-Secure              -63  1.364643e+08  1.706942e+08
# 35           eduroam              -63  4.534025e+07  5.489408e+07
# 36  WolfieNet-Secure              -58  5.898175e+06  1.469534e+07
#
#                     location   latitude  longitude         wifi_name
# 0                 SchomburgA  40.913390 -73.132210           eduroam
# 1                 SchomburgA  40.913390 -73.132210  WolfieNet-Secure
# 2                 SchomburgA  40.913137 -73.132169  WolfieNet-Secure
# 3   Humanities2ndFloorLounge  40.914110 -73.121030           eduroam
# 4   Humanities2ndFloorLounge  40.914110 -73.121030  WolfieNet-Secure
# 5            StudentUnion-F2  40.917092 -73.122437           eduroam
# 6            StudentUnion-F2  40.917092 -73.122437  WolfieNet-Secure
# 7          EngineeringLounge  40.913090 -73.124550           eduroam
# 8          EngineeringLounge  40.913090 -73.124550  WolfieNet-Secure
# 9          Engineering145GBM  40.912980 -73.124400           eduroam
# 10         Engineering145GBM  40.912980 -73.124400  WolfieNet-Secure
# 11                WangLounge  40.915850 -73.119720           eduroam
# 12                WangLounge  40.915850 -73.119720  WolfieNet-Secure
# 13            FreyHall-Lobby  40.915635 -73.123666           eduroam
# 14            FreyHall-Lobby  40.915635 -73.123666  WolfieNet-Secure
# 15       NorthReadingRoom-F2  40.916027 -73.122614           eduroam
# 16       NorthReadingRoom-F2  40.916027 -73.122614  WolfieNet-Secure
# 17                 SAC-Lobby  40.914629 -73.124226           eduroam
# 18                 SAC-Lobby  40.914629 -73.124226  WolfieNet-Secure
# 19                    NCS106  40.917610 -73.081060           eduroam
# 20                    NCS106  40.917610 -73.081060  WolfieNet-Secure
# 21                  RothCafe  40.910810 -73.123870           eduroam
# 22                  RothCafe  40.910810 -73.123870  WolfieNet-Secure
# 23                    NCS120  40.912720 -73.123790           eduroam
# 24                    NCS120  40.912720 -73.123790  WolfieNet-Secure
# 25        CentralReadingRoom  40.915300 -73.122491           eduroam
# 26        CentralReadingRoom  40.915300 -73.122491  WolfieNet-Secure
# 27           StudentUnion-F1  40.917065 -73.122420           eduroam
# 28           StudentUnion-F1  40.917065 -73.122420  WolfieNet-Secure
# 29       HumanitiesGlassArea  40.914210 -73.121340           eduroam
# 30       HumanitiesGlassArea  40.914210 -73.121340  WolfieNet-Secure
# 31             SAC-Cafeteria  40.914734 -73.123341           eduroam
# 32             SAC-Cafeteria  40.914734 -73.123341  WolfieNet-Secure
# 33                   Jasmine  40.916240 -73.119690           eduroam
# 34                   Jasmine  40.916240 -73.119690  WolfieNet-Secure
# 35       NorthReadingRoom-F1  40.916034 -73.122723           eduroam
# 36       NorthReadingRoom-F1  40.916034 -73.122723  WolfieNet-Secure

# %%
website_df
# Out:
#                  destination  packet_transmit  packet_receive  \
# 0                 google.com             40.0            40.0
# 1                youtube.com             40.0            39.0
# 2                  tmall.com             40.0            40.0
# 3               facebook.com             40.0            39.0
# 4                     qq.com             40.0            40.0
# ...                      ...              ...             ...
# 1290             discord.com             40.0            40.0
# 1291             quizlet.com             40.0            40.0
# 1292              github.com             40.0            40.0
# 1293  psns.cc.stonybrook.edu             40.0            40.0
# 1294       stackoverflow.com             40.0            40.0
#
#       packet_loss_count  packet_loss_rate  rtt_min  rtt_avg  rtt_max  \
# 0                   0.0               0.0    9.547   12.937   52.278
# 1                   1.0               2.5   10.032   11.614   13.654
# 2                   0.0               0.0  247.545  310.718  370.803
# 3                   1.0               2.5   11.671   13.271   17.899
# 4                   0.0               0.0  222.477  298.483  477.298
# ...                 ...               ...      ...      ...      ...
# 1290                0.0               0.0    6.849   77.831  342.538
# 1291                0.0               0.0    9.545   76.555  306.264
# 1292                0.0               0.0   15.892   77.098  244.655
# 1293                0.0               0.0    9.131   76.306  324.948
# 1294                0.0               0.0   13.851   59.703  201.477
#
#       rtt_mdev  packet_duplicate_count  packet_duplicate_rate     jitter  \
# 0        7.213                     0.0                    0.0   3.751795
# 1        0.744                     0.0                    0.0   0.978947
# 2       34.253                     0.0                    0.0  38.846154
# 3        1.166                     0.0                    0.0   1.123684
# 4       66.467                     0.0                    0.0  66.641026
# ...        ...                     ...                    ...        ...
# 1290    92.057                     0.0                    0.0  48.602256
# 1291    63.958                     0.0                    0.0  50.058256
# 1292    62.112                     0.0                    0.0  42.872538
# 1293    74.961                     0.0                    0.0  51.688077
# 1294    47.329                     0.0                    0.0  40.251538
#
#       loss_rate  loss_count             location   latitude  longitude  \
# 0           0.0         0.0           SchomburgA  40.913390 -73.132210
# 1           2.5         1.0           SchomburgA  40.913390 -73.132210
# 2           0.0         0.0           SchomburgA  40.913390 -73.132210
# 3           2.5         1.0           SchomburgA  40.913390 -73.132210
# 4           0.0         0.0           SchomburgA  40.913390 -73.132210
# ...         ...         ...                  ...        ...        ...
# 1290        0.0         0.0  NorthReadingRoom-F1  40.916034 -73.122723
# 1291        0.0         0.0  NorthReadingRoom-F1  40.916034 -73.122723
# 1292        0.0         0.0  NorthReadingRoom-F1  40.916034 -73.122723
# 1293        0.0         0.0  NorthReadingRoom-F1  40.916034 -73.122723
# 1294        0.0         0.0  NorthReadingRoom-F1  40.916034 -73.122723
#
#              wifi_name
# 0              eduroam
# 1              eduroam
# 2              eduroam
# 3              eduroam
# 4              eduroam
# ...                ...
# 1290  WolfieNet-Secure
# 1291  WolfieNet-Secure
# 1292  WolfieNet-Secure
# 1293  WolfieNet-Secure
# 1294  WolfieNet-Secure
#
# [1284 rows x 18 columns]

# %%
final_df = pd.merge(network_df, website_df, how='left')
final_df
# Out:
#                   ssid  signal_strength      download        upload  \
# 0              eduroam              -44  2.225958e+08  2.192850e+08
# 1              eduroam              -44  2.225958e+08  2.192850e+08
# 2              eduroam              -44  2.225958e+08  2.192850e+08
# 3              eduroam              -44  2.225958e+08  2.192850e+08
# 4              eduroam              -44  2.225958e+08  2.192850e+08
# ...                ...              ...           ...           ...
# 1279  WolfieNet-Secure              -58  5.898175e+06  1.469534e+07
# 1280  WolfieNet-Secure              -58  5.898175e+06  1.469534e+07
# 1281  WolfieNet-Secure              -58  5.898175e+06  1.469534e+07
# 1282  WolfieNet-Secure              -58  5.898175e+06  1.469534e+07
# 1283  WolfieNet-Secure              -58  5.898175e+06  1.469534e+07
#
#                  location   latitude  longitude         wifi_name  \
# 0              SchomburgA  40.913390 -73.132210           eduroam
# 1              SchomburgA  40.913390 -73.132210           eduroam
# 2              SchomburgA  40.913390 -73.132210           eduroam
# 3              SchomburgA  40.913390 -73.132210           eduroam
# 4              SchomburgA  40.913390 -73.132210           eduroam
# ...                   ...        ...        ...               ...
# 1279  NorthReadingRoom-F1  40.916034 -73.122723  WolfieNet-Secure
# 1280  NorthReadingRoom-F1  40.916034 -73.122723  WolfieNet-Secure
# 1281  NorthReadingRoom-F1  40.916034 -73.122723  WolfieNet-Secure
# 1282  NorthReadingRoom-F1  40.916034 -73.122723  WolfieNet-Secure
# 1283  NorthReadingRoom-F1  40.916034 -73.122723  WolfieNet-Secure
#
#                  destination  packet_transmit  ...  packet_loss_rate  rtt_min  \
# 0                 google.com             40.0  ...               0.0    9.547
# 1                youtube.com             40.0  ...               2.5   10.032
# 2                  tmall.com             40.0  ...               0.0  247.545
# 3               facebook.com             40.0  ...               2.5   11.671
# 4                     qq.com             40.0  ...               0.0  222.477
# ...                      ...              ...  ...               ...      ...
# 1279             discord.com             40.0  ...               0.0    6.849
# 1280             quizlet.com             40.0  ...               0.0    9.545
# 1281              github.com             40.0  ...               0.0   15.892
# 1282  psns.cc.stonybrook.edu             40.0  ...               0.0    9.131
# 1283       stackoverflow.com             40.0  ...               0.0   13.851
#
#       rtt_avg  rtt_max  rtt_mdev  packet_duplicate_count  \
# 0      12.937   52.278     7.213                     0.0
# 1      11.614   13.654     0.744                     0.0
# 2     310.718  370.803    34.253                     0.0
# 3      13.271   17.899     1.166                     0.0
# 4     298.483  477.298    66.467                     0.0
# ...       ...      ...       ...                     ...
# 1279   77.831  342.538    92.057                     0.0
# 1280   76.555  306.264    63.958                     0.0
# 1281   77.098  244.655    62.112                     0.0
# 1282   76.306  324.948    74.961                     0.0
# 1283   59.703  201.477    47.329                     0.0
#
#       packet_duplicate_rate     jitter  loss_rate  loss_count
# 0                       0.0   3.751795        0.0         0.0
# 1                       0.0   0.978947        2.5         1.0
# 2                       0.0  38.846154        0.0         0.0
# 3                       0.0   1.123684        2.5         1.0
# 4                       0.0  66.641026        0.0         0.0
# ...                     ...        ...        ...         ...
# 1279                    0.0  48.602256        0.0         0.0
# 1280                    0.0  50.058256        0.0         0.0
# 1281                    0.0  42.872538        0.0         0.0
# 1282                    0.0  51.688077        0.0         0.0
# 1283                    0.0  40.251538        0.0         0.0
#
# [1284 rows x 22 columns]

# %%
final_df.to_csv('integrated_data.csv')
